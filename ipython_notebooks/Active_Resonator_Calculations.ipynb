# %%
from IPython.display import Image
import numpy as np
Image(filename='afr_circuit.png')

# %%
def output_noise_temp(noise_temp_forward, noise_temp_cavity, noise_temp_reverse, gain, theta):
    RHS = s[1][2]**2 * noise_temp_reverse + s[1][3]**2 * noise_temp_cavity + s[2][1]**2 * gain * noise_temp_forward
    LH_factor = 1 + s[2][1]**2 * gain - 2 * s[2][1] * np.sqrt(gain) * np.cos(theta)
    return RHS / LH_factor
